# %%
import ipywidgets as widgets
from IPython.display import display
from IPython.display import Image as image
from IPython.display import HTML as html

# %%
import selenium.webdriver
from selenium.webdriver.common.by import By

# %%
html_tag = By.TAG_NAME
html_class= By.CLASS_NAME

# %%
options = selenium.webdriver.ChromeOptions()

# %%
options.add_argument('headless')

# %%
browser = selenium.webdriver.Chrome(options=options)

# %%
browser.get('https://ipinfo.io')

# %%
browser.page_source
# Out:
# '<html><head>\n    <title>IP Address API and Data Solutions - geolocation, company, carrier info, type and more - IPinfo IP Address Geolocation API</title>\n    <meta charset="utf-8">\n    <meta name="apple-itunes-app" content="app-id=917634022">\n    <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no, user-scalable=no">\n    <meta name="description" content="We\'re the trusted source for IP address data, handling 12 billion IP geolocation API requests per month for over 1,000 businesses and 100,000+ developers">\n\n    <link rel="manifest" href="/static/manifest.json">\n\n    <link rel="icon" sizes="48x48" href="/static/deviceicons/android-icon-48x48.png">\n    <link rel="icon" sizes="96x96" href="/static/deviceicons/android-icon-96x96.png">\n    <link rel="icon" sizes="192x192" href="/static/deviceicons/android-icon-192x192.png">\n\n    <link rel="apple-touch-icon-precomposed" href="/static/deviceicons/apple-icon-precomposed.png">\n\n    <link type
# ...

# %%
html(browser.page_source)
# Out:
# <html><head>
#     <title>IP Address API and Data Solutions - geolocation, company, carrier info, type and more - IPinfo IP Address Geolocation API</title>
#     <meta charset="utf-8">
#     <meta name="apple-itunes-app" content="app-id=917634022">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no, user-scalable=no">
#     <meta name="description" content="We're the trusted source for IP address data, handling 12 billion IP geolocation API requests per month for over 1,000 businesses and 100,000+ developers">
#
#     <link rel="manifest" href="/static/manifest.json">
#
#     <link rel="icon" sizes="48x48" href="/static/deviceicons/android-icon-48x48.png">
#     <link rel="icon" sizes="96x96" href="/static/deviceicons/android-icon-96x96.png">
#     <link rel="icon" sizes="192x192" href="/static/deviceicons/android-icon-192x192.png">
#
#     <link rel="apple-touch-icon-precomposed" href="/static/deviceicons/apple-icon-precomposed.png">
#
# ...

# %%
vars(select)
# Out:
# mappingproxy({'__module__': 'selenium.webdriver.common.by',
#               '__doc__': '\n    Set of supported locator strategies.\n    ',
#               'ID': 'id',
#               'XPATH': 'xpath',
#               'LINK_TEXT': 'link text',
#               'PARTIAL_LINK_TEXT': 'partial link text',
#               'NAME': 'name',
#               'TAG_NAME': 'tag name',
#               'CLASS_NAME': 'class name',
#               'CSS_SELECTOR': 'css selector',
#               '__dict__': <attribute '__dict__' of 'By' objects>,
#               '__weakref__': <attribute '__weakref__' of 'By' objects>})

# %%
browser.find_element(select.tag_name, 'title')
# Out:
# -------------------------------------------------------------
# AttributeError              Traceback (most recent call last)
# <ipython-input-28-63a07eca73f5> in <module>
# ----> 1 browser.find_element(select.tag_name, 'title')
#
# AttributeError: type object 'By' has no attribute 'tag_name'

# %%
vars(By)
# Out:
# mappingproxy({'__module__': 'selenium.webdriver.common.by',
#               '__doc__': '\n    Set of supported locator strategies.\n    ',
#               'ID': 'id',
#               'XPATH': 'xpath',
#               'LINK_TEXT': 'link text',
#               'PARTIAL_LINK_TEXT': 'partial link text',
#               'NAME': 'name',
#               'TAG_NAME': 'tag name',
#               'CLASS_NAME': 'class name',
#               'CSS_SELECTOR': 'css selector',
#               '__dict__': <attribute '__dict__' of 'By' objects>,
#               '__weakref__': <attribute '__weakref__' of 'By' objects>})

# %%
browser.find_element(html_tag, 'h1')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3732ad76ba1d5deb99bf99522cda4490", element="c1aedd68-4bc4-4ba4-ab49-6e414ef36d67")>

# %%
browser.find_element(html_tag, 'title')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3732ad76ba1d5deb99bf99522cda4490", element="1b2d7457-0ef8-4413-be3d-916cf8269a7c")>

# %%
logo = browser.find_element(html_class, 'navbar-brand')

# %%
logo.location
# Out:
# {'x': 31, 'y': 30}

# %%
logo.size
# Out:
# {'height': 34, 'width': 116}

# %%
image( logo.screenshot_as_png )

# %%
with open('logo.png', 'wb') as file:
    file.write(logo.screenshot_as_png)
